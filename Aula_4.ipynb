# %% [markdown]
# ## Diamonds Dataset
# https://ggplot2.tidyverse.org/reference/diamonds.html
#
# **A data frame with 53940 rows and 10 variables:**
#
# ### price
# *   price in US dollars ($326–$18,823)
#
# ### carat
# *   weight of the diamond (0.2–5.01)
#
# ### cut
# *   quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# ### color
# *   diamond colour, from D (best) to J (worst)
#
# ### clarity
# *   a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# ### x
# *   length in mm (0–10.74)
#
# ### y
# *   width in mm (0–58.9)
#
# ### z
# *   depth in mm (0–31.8)
#
# ### depth
# *   total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43–79)
#
# ### table
# *   width of top of diamond relative to widest point (43–95)

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('diamonds')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
df['color'].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
df[['clarity', 'color', 'depth']].head()
# Out:
#   clarity color  depth
# 0     SI2     E   61.5
# 1     SI1     E   59.8
# 2     VS1     E   56.9
# 3     VS2     I   62.4
# 4     SI2     J   63.3

# %%
df.loc[19876]
# Out:
# carat       1.31
# cut        Ideal
# color          H
# clarity      VS1
# depth       61.5
# table       55.0
# price       8429
# x           7.02
# y           7.05
# z           4.33
# Name: 19876, dtype: object

# %%
df.iloc[18643]
# Out:
# carat       1.35
# cut        Ideal
# color          H
# clarity      SI1
# depth       61.5
# table       58.0
# price       7609
# x           7.08
# y           7.11
# z           4.36
# Name: 18643, dtype: object

# %%
df.iloc[:5, :3]
# Out:
#    carat      cut color
# 0   0.23    Ideal     E
# 1   0.21  Premium     E
# 2   0.23     Good     E
# 3   0.29  Premium     I
# 4   0.31     Good     J

# %%
df[['clarity', 'color', 'depth']].iloc[5]
# Out:
# clarity    VVS2
# color         J
# depth      62.8
# Name: 5, dtype: object

# %%
premium = df[df['cut'] == 'Premium']
print(premium)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %%
good = df[df['cut'] == 'Good']
print(good)
# Out:
#        carat   cut color clarity  depth  table  price     x     y     z
# 2       0.23  Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4       0.31  Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10      0.30  Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 17      0.30  Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18      0.30  Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# ...      ...   ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53913   0.80  Good     G     VS2   64.2   58.0   2753  5.84  5.81  3.74
# 53914   0.84  Good     I     VS1   63.7   59.0   2753  5.94  5.90  3.77
# 53916   0.74  Good     D     SI1   63.1   59.0   2753  5.71  5.74  3.61
# 53927   0.79  Good     F     SI1   58.1   59.0   2756  6.06  6.13  3.54
# 53936   0.72  Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
#
# [4906 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# Calculate the count of each color
color_counts = df['color'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(color_counts, labels=color_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Diamond Colors')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Define a color palette that approximates the diamond color grades from D to J.
# D: Colorless (approximated by a light blue)
# E: Colorless (approximated by a slightly darker blue)
# F: Colorless (approximated by a pale blue)
# G: Near colorless (approximated by a very pale yellow)
# H: Near colorless (approximated by a light yellow)
# I: Faint yellow (approximated by a yellow)
# J: Very light yellow (approximated by an orange-yellow)
diamond_colors_palette = ['#ADD8E6', '#87CEFA', '#B0E0E6', '#FFFFE0', '#FFFACD', '#FFFF00', '#FFA500']

# Reorder the palette to match the color categories from df['color'].value_counts()
# The order is G, E, F, H, D, I, J
ordered_palette = [diamond_colors_palette[3], # G
                   diamond_colors_palette[1], # E
                   diamond_colors_palette[2], # F
                   diamond_colors_palette[4], # H
                   diamond_colors_palette[0], # D
                   diamond_colors_palette[5], # I
                   diamond_colors_palette[6]] # J

# %%
# Create a pie chart with the specified color palette
plt.figure(figsize=(8, 8))
plt.pie(color_counts, labels=color_counts.index, autopct='%1.1f%%', startangle=90, colors=ordered_palette)
plt.title('Distribution of Diamond Colors')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.groupby('color')['price'].mean()
# Out:
# /tmp/ipython-input-3121792941.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('color')['price'].mean()
# color
# D    3169.954096
# E    3076.752475
# F    3724.886397
# G    3999.135671
# H    4486.669196
# I    5091.874954
# J    5323.818020
# Name: price, dtype: float64

# %%
df.groupby('clarity')['price'].mean()
# Out:
# /tmp/ipython-input-3809015613.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('clarity')['price'].mean()
# clarity
# IF      2864.839106
# VVS1    2523.114637
# VVS2    3283.737071
# VS1     3839.455391
# VS2     3924.989395
# SI1     3996.001148
# SI2     5063.028606
# I1      3924.168691
# Name: price, dtype: float64

# %%
df.groupby(['color', 'clarity'])['price'].mean().sort_values(ascending=False)
# Out:
# /tmp/ipython-input-3595997946.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['color', 'clarity'])['price'].mean().sort_values(ascending=False)
# color  clarity
# D      IF         8307.369863
# I      SI2        7002.649123
# J      SI2        6520.958246
# H      SI2        6099.895074
# I      VS2        5690.505560
#        SI1        5355.019663
# J      VS2        5311.058824
#        I1         5254.060000
#        SI1        5186.048000
#        VVS2       5142.396947
# H      SI1        5032.414945
# G      SI2        5021.684109
# J      VS1        4884.461255
# H      VS2        4722.414486
# I      VS1        4633.183992
# F      SI2        4472.625233
# H      I1         4453.413580
# G      VS2        4416.256498
# I      I1         4302.184783
# E      SI2        4173.826036
# G      VS1        4131.362197
# J      VVS1       4034.175676
# D      SI2        3931.101460
#        I1         3863.023810
# G      VVS2       3845.283437
# F      VS1        3796.717742
# H      VS1        3780.688623
# G      SI1        3774.787449
# F      VS2        3756.795093
#        SI1        3714.225716
# E      IF         3668.506329
# G      I1         3545.693333
# E      I1         3488.421569
# F      VVS2       3475.512821
# J      IF         3363.882353
# D      VVS2       3351.128391
# F      I1         3342.181818
# E      SI1        3161.838005
# D      VS1        3030.158865
#        SI1        2976.146423
# I      VVS2       2968.232877
# D      VVS1       2947.912698
# G      VVS1       2866.820821
# E      VS1        2856.294301
# F      VVS1       2804.276567
# E      VS2        2750.941700
# F      IF         2750.836364
# H      VVS2       2649.067434
# D      VS2        2587.225692
# G      IF         2558.033774
# E      VVS2       2499.674067
# H      IF         2287.869565
# E      VVS1       2219.820122
# I      VVS1       2034.861972
#        IF         1994.937063
# H      VVS1       1845.658120
# Name: price, dtype: float64

# %%
df.groupby(['color', 'clarity']).agg(
    mean_price=('price', 'mean'),
    median_price=('price', 'median'),
    min_price=('price', 'min'),
    max_price=('price', 'max')
)
# Out:
# /tmp/ipython-input-777789135.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['color', 'clarity']).agg(
#                 mean_price  median_price  min_price  max_price
# color clarity
# D     IF       8307.369863        4632.0        893      18542
#       VVS1     2947.912698        1427.0        425      17932
#       VVS2     3351.128391        1257.0        452      17545
#       VS1      3030.158865        1860.0        357      17936
#       VS2      2587.225692        1688.0        357      18318
#       SI1      2976.146423        1759.0        452      18468
#       SI2      3931.101460        3468.0        413      18693
#       I1       3863.023810        3774.5        361      15964
# E     IF       3668.506329        1208.0        492      18700
#       VVS1     2219.820122        1017.0        439      16256
#       VVS2     2499.674067        1056.0        458      18188
#       VS1      2856.294301        1668.0        327      18729
#       VS2      2750.941700        1662.0        337      18557
#       SI1      3161.838005        2257.5        326      18731
#       SI2      4173.826036        3612.0        326      18477
#       I1       3488.421569        3296.5        345      11548
# F     IF       2750.836364        1046.0        485      18552
#       VVS1     2804.276567        1140.5        458      18777
#       VVS2     3475.512821        2041.0        425      18614
#       VS1      3796.717742        2036.5        357      18780
#       VS2      3756.795093        1786.0        357      18791
#       SI1      3714.225716        2657.0        342      18759
#       SI2      4472.625233        3812.0        394      18784
#       I1       3342.181818        2856.0        394      10685
# G     IF       2558.033774        1052.0        536      18806
#       VVS1     2866.820821        1114.0        395      18445
#       VVS2     3845.283437        1906.0        354      18768
#       VS1      4131.362197        1891.5        382      18419
#       VS2      4416.256498        2770.0        369      18700
#       SI1      3774.787449        2604.0        363      18818
#       SI2      5021.684109        4027.0        361      18804
#       I1       3545.693333        2999.5        467      13203
# H     IF       2287.869565        1074.0        369      16300
#       VVS1     1845.658120         968.0        401      14603
#       VVS2     2649.067434         881.0        378      17267
#       VS1      3780.688623        2175.0        338      18522
#       VS2      4722.414486        4082.0        367      18659
#       SI1      5032.414945        4564.0        337      18803
#       SI2      6099.895074        4547.0        362      18745
#       I1       4453.413580        3669.0        452      17329
# I     IF       1994.937063         895.0        587      12725
#       VVS1     2034.861972        1080.0        336      15654
#       VVS2     2968.232877        1369.0        412      15952
#       VS1      4633.183992        2847.0        355      18795
#       VS2      5690.505560        4199.0        334      18823
#       SI1      5355.019663        4368.0        377      18797
#       SI2      7002.649123        5170.5        348      18756
#       I1       4302.184783        3054.5       1014      16193
# J     IF       3363.882353        1061.0        489      18594
#       VVS1     4034.175676        1768.0        461      17891
#       VVS2     5142.396947        4098.0        336      17214
#       VS1      4884.461255        3557.5        340      18706
#       VS2      5311.058824        4338.0        357      18701
#       SI1      5186.048000        4275.5        339      18508
#       SI2      6520.958246        4656.0        335      18710
#       I1       5254.060000        4546.0        945      18531

# %%
df.groupby(['color', 'clarity']).agg(
    mean_price=('price', 'mean'),
    median_price=('price', 'median'),
    min_price=('price', 'min'),
    max_price=('price', 'max')
).sort_values(by='max_price', ascending=False)
# Out:
# /tmp/ipython-input-459811669.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['color', 'clarity']).agg(
#                 mean_price  median_price  min_price  max_price
# color clarity
# I     VS2      5690.505560        4199.0        334      18823
# G     SI1      3774.787449        2604.0        363      18818
#       IF       2558.033774        1052.0        536      18806
#       SI2      5021.684109        4027.0        361      18804
# H     SI1      5032.414945        4564.0        337      18803
# I     SI1      5355.019663        4368.0        377      18797
#       VS1      4633.183992        2847.0        355      18795
# F     VS2      3756.795093        1786.0        357      18791
#       SI2      4472.625233        3812.0        394      18784
#       VS1      3796.717742        2036.5        357      18780
#       VVS1     2804.276567        1140.5        458      18777
# G     VVS2     3845.283437        1906.0        354      18768
# F     SI1      3714.225716        2657.0        342      18759
# I     SI2      7002.649123        5170.5        348      18756
# H     SI2      6099.895074        4547.0        362      18745
# E     SI1      3161.838005        2257.5        326      18731
#       VS1      2856.294301        1668.0        327      18729
# J     SI2      6520.958246        4656.0        335      18710
#       VS1      4884.461255        3557.5        340      18706
#       VS2      5311.058824        4338.0        357      18701
# G     VS2      4416.256498        2770.0        369      18700
# E     IF       3668.506329        1208.0        492      18700
# D     SI2      3931.101460        3468.0        413      18693
# H     VS2      4722.414486        4082.0        367      18659
# F     VVS2     3475.512821        2041.0        425      18614
# J     IF       3363.882353        1061.0        489      18594
# E     VS2      2750.941700        1662.0        337      18557
# F     IF       2750.836364        1046.0        485      18552
# D     IF       8307.369863        4632.0        893      18542
# J     I1       5254.060000        4546.0        945      18531
# H     VS1      3780.688623        2175.0        338      18522
# J     SI1      5186.048000        4275.5        339      18508
# E     SI2      4173.826036        3612.0        326      18477
# D     SI1      2976.146423        1759.0        452      18468
# G     VVS1     2866.820821        1114.0        395      18445
#       VS1      4131.362197        1891.5        382      18419
# D     VS2      2587.225692        1688.0        357      18318
# E     VVS2     2499.674067        1056.0        458      18188
# D     VS1      3030.158865        1860.0        357      17936
#       VVS1     2947.912698        1427.0        425      17932
# J     VVS1     4034.175676        1768.0        461      17891
# D     VVS2     3351.128391        1257.0        452      17545
# H     I1       4453.413580        3669.0        452      17329
#       VVS2     2649.067434         881.0        378      17267
# J     VVS2     5142.396947        4098.0        336      17214
# H     IF       2287.869565        1074.0        369      16300
# E     VVS1     2219.820122        1017.0        439      16256
# I     I1       4302.184783        3054.5       1014      16193
# D     I1       3863.023810        3774.5        361      15964
# I     VVS2     2968.232877        1369.0        412      15952
#       VVS1     2034.861972        1080.0        336      15654
# H     VVS1     1845.658120         968.0        401      14603
# G     I1       3545.693333        2999.5        467      13203
# I     IF       1994.937063         895.0        587      12725
# E     I1       3488.421569        3296.5        345      11548
# F     I1       3342.181818        2856.0        394      10685

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get the aggregated data
agg_data = df.groupby(['color', 'clarity']).agg(
    mean_price=('price', 'mean'),
    median_price=('price', 'median'),
    min_price=('price', 'min'),
    max_price=('price', 'max')
)

# You can choose which price statistic to visualize on the heatmap.
# Let's start with the mean price.
mean_price_pivot = agg_data['mean_price'].unstack()

# Create the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(mean_price_pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title('Mean Diamond Price by Color and Clarity')
plt.xlabel('Clarity')
plt.ylabel('Color')
plt.show()
# Out:
# /tmp/ipython-input-3084532006.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_data = df.groupby(['color', 'clarity']).agg(

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='color', y='price', hue='clarity', data=df)
plt.title('Distribution of Diamond Prices by Color and Clarity')
plt.xlabel('Color')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15, 8))
# Using the custom color palette might make the plot less readable due to the number of clarity levels.
# Therefore, we will use the default seaborn palette for better visual separation.
sns.boxplot(x='color', y='price', hue='clarity', data=df)
plt.title('Distribution of Diamond Prices by Color and Clarity')
plt.xlabel('Color')
plt.ylabel('Price')
plt.show()
